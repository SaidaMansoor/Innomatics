# %% [markdown]
# # Ques - 1

# %%
hel = "Hello World!"
print(hel)
# Out:
# Hello World!

# %% [markdown]
# # Ques - 2

# %%
n = int(input().strip())

if n % 2 == 0:
    if 2<=n<=5:
        print("Not Weird")
    elif 6<=n<=20:
        print("Weird")
    else:
        print("Not Weird")
else:
    print("Weird")
# Out:
#  99
# Weird

# %% [markdown]
# # Ques 3

# %%
a = int(input())
b = int(input())

print(a+b)
print(a-b)
print(a*b)
# Out:
#  3
#  4
# 7
# -1
# 12

# %% [markdown]
# # Ques 4

# %%
a = int(input())
b = int(input())

print(a//b)
print(a/b)
# Out:
#  4
#  5
# 0
# 0.8

# %% [markdown]
# # Ques 5

# %%
n = int(input())

for i in range(n):
    if i<0:
        break
    else:
        print(i**2)
# Out:
#  4
# 0
# 1
# 4
# 9

# %% [markdown]
# # Ques 6

# %%
def is_leap(year):
    leap = False
    
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    else: 
        leap = False           
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  4450
# False

# %% [markdown]
# # Ques 7
